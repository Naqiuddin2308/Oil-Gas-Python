# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter.font as tkFont
import numpy as np
from tkinter import scrolledtext

# %% [markdown]
# ## With Logo

# %% [markdown]
# ## 1st Attempt

# %%
root = Tk()
root.geometry("1700x1200")
root.title('EQ-AIMS - EQURVE GAS')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


# WIDGET CREATION

# Header
AppDescrip = Label(root, text="EQURVE - GAS", font=lato18)
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# LAYOUT

# Header
AppDescrip.grid(row=3, column=0, columnspan=7, pady=(0,20))
Equrve_imagelabel.grid(row=0, column=0, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=30, columnspan=10, pady=(10,2))



# Creating Menubar
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 2nd Attempt

# %%
# root = Tk()
# root.geometry("1070x600")
# root.title('EQ-AIMS - EQURVE GAS')
# root.config(background='light grey')
# root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

# lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
# lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
# roboto8 = tkFont.Font(family="Roboto",size=8)
# lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
# lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


# ### WIDGET CREATION ###

# # Header
# app_head = Label(root, text="EQURVE - GAS", font=lato24)


# # Type Curve Editor

# TC_label = Label(root, text='Type Curve Editor', font=lato10, width=40, bg='#000000', fg='#ffffff')
# res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey')
# inc_label = Label(root, text='Increment', font=roboto8,  bg='light grey')
# TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8,  bg='light grey')

# res_entry = Entry(root, font=roboto8, width=15)
# inc_entry = Entry(root, font=roboto8, width=15)
# TC_EUR_entry = Entry(root, font=roboto8, width=15)


# ### LAYOUT ###

# # Header
# app_head.grid(row=3, column=0, columnspan=7,padx=400, pady=50)


# # Type Curve Editor

# TC_label.grid(row=5, column=0, columnspan=2)
# res_label.grid(row=6, column=0)
# inc_label.grid(row=6, column=1)
# TC_EUR_label.grid(row=6, column=2)

# res_entry.grid(row=7, column=0)
# inc_entry.grid(row=7, column=1)
# TC_EUR_entry.grid(row=7, column=2)


# # Creating Menubar
# menubar = Menu(root)

# # Adding File Menu and commands
# file = Menu(menubar, tearoff=0)
# menubar.add_cascade(label='File', menu=file)
# file.add_command(label='New File', command=None)
# file.add_command(label='Open...', command=None)
# file.add_command(label='Save', command=None)
# file.add_separator
# file.add_command(label='Exit', command=root.destroy)

# # Adding Edit Menu and commands
# edit = Menu(menubar, tearoff=0)
# menubar.add_cascade(label='Edit', menu=edit)
# edit.add_command(label='Cut', command=None)
# edit.add_command(label='Copy', command=None)
# edit.add_command(label='Paste', command=None)
# edit.add_command(label='Select All', command=None)
# edit.add_separator
# edit.add_command(label='Find...', command=None)
# edit.add_command(label='Find Again', command=None)

# # Adding Help Menu
# help_=Menu(menubar, tearoff=0)
# menubar.add_cascade(label='Help', menu=help_)
# help_.add_command(label='Demo', command=None)
# help_.add_separator
# help_.add_command(label='About', command=None)

# # Display Menu
# root.config(menu=menubar)
# root.mainloop()

# %% [markdown]
# ## 3rd Attempt

# %%
root = Tk()
root.geometry("1300x800")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato24, bg='gold')
Equrve_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo/equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo//eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)

# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=40, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)
TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)
TC_EUR_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=40, bg='#000000', fg='#ffffff')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)


### LAYOUT ###

# Header
app_head.grid(row=3, column=0, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
# Equrve_imagelabel.grid(row=0, column=0, columnspan=7, pady=(10,2))
# Eqaims_imagelabel.grid(row=0, column=6, columnspan=2, pady=(10,2))

# FIELD INFO
# Label
Field_label.grid(row=5, column=0, columnspan=2, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
TC_EUR_label.grid(row=8, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))
TC_EUR_entry.grid(row=8, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, columnspan=2, pady=(0,10), padx=(10,0))
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))



# Entry for Gas Rate
# l1_entry.grid(row=12, column=1, pady=0, padx=(8, 0))
# l2_entry.grid(row=13, column=1, pady=0, padx=(8, 0))
# l3_entry.grid(row=14, column=1, pady=0, padx=(8, 0))
# l4_entry.grid(row=15, column=1, pady=0, padx=(8, 0))
# l5_entry.grid(row=16, column=1, pady=0, padx=(8, 0))
# l6_entry.grid(row=17, column=1, pady=0, padx=(8, 0))
# l7_entry.grid(row=18, column=1, pady=0, padx=(8, 0))
# l8_entry.grid(row=19, column=1, pady=0, padx=(8, 0))

# Entry for Gas Rate
l1_entry.grid(row=12, column=1)
l2_entry.grid(row=13, column=1)
l3_entry.grid(row=14, column=1)
l4_entry.grid(row=15, column=1)
l5_entry.grid(row=16, column=1)
l6_entry.grid(row=17, column=1)
l7_entry.grid(row=18, column=1)
l8_entry.grid(row=19, column=1)

# Entry for CGR
l9_entry.grid(row=12, column=2)
l10_entry.grid(row=13, column=2)
l11_entry.grid(row=14, column=2)
l12_entry.grid(row=15, column=2)
l13_entry.grid(row=16, column=2)
l14_entry.grid(row=17, column=2)
l15_entry.grid(row=18, column=2)
l16_entry.grid(row=19, column=2)

# Entry for WGR
l17_entry.grid(row=12, column=3)
l18_entry.grid(row=13, column=3)
l19_entry.grid(row=14, column=3)
l20_entry.grid(row=15, column=3)
l21_entry.grid(row=16, column=3)
l22_entry.grid(row=17, column=3)
l23_entry.grid(row=18, column=3)
l24_entry.grid(row=19, column=3)

# Entry for Pres
l25_entry.grid(row=12, column=4)
l26_entry.grid(row=13, column=4)
l27_entry.grid(row=14, column=4)
l28_entry.grid(row=15, column=4)
l29_entry.grid(row=16, column=4)
l30_entry.grid(row=17, column=4)
l31_entry.grid(row=18, column=4)
l32_entry.grid(row=19, column=4)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 4th Attempt

# %%
root = Tk()
root.geometry("1300x1300")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato24, bg='gold')
Equrve_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo/equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo//eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)

# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=40, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)
TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)
TC_EUR_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=40, bg='#000000', fg='#ffffff')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)

table1 = scrolledtext.ScrolledText(root, height=50, width=50) 
table1.grid(row=10, column=11)



### LAYOUT ###

# Header
app_head.grid(row=3, column=0, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
# Equrve_imagelabel.grid(row=0, column=0, columnspan=7, pady=(10,2))
# Eqaims_imagelabel.grid(row=0, column=6, columnspan=2, pady=(10,2))

# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
TC_EUR_label.grid(row=8, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))
TC_EUR_entry.grid(row=8, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))



# Entry for Gas Rate
# l1_entry.grid(row=12, column=1, pady=0, padx=(8, 0))
# l2_entry.grid(row=13, column=1, pady=0, padx=(8, 0))
# l3_entry.grid(row=14, column=1, pady=0, padx=(8, 0))
# l4_entry.grid(row=15, column=1, pady=0, padx=(8, 0))
# l5_entry.grid(row=16, column=1, pady=0, padx=(8, 0))
# l6_entry.grid(row=17, column=1, pady=0, padx=(8, 0))
# l7_entry.grid(row=18, column=1, pady=0, padx=(8, 0))
# l8_entry.grid(row=19, column=1, pady=0, padx=(8, 0))

# Entry for Gas Rate
l1_entry.grid(row=12, column=1)
l2_entry.grid(row=13, column=1)
l3_entry.grid(row=14, column=1)
l4_entry.grid(row=15, column=1)
l5_entry.grid(row=16, column=1)
l6_entry.grid(row=17, column=1)
l7_entry.grid(row=18, column=1)
l8_entry.grid(row=19, column=1)

# Entry for CGR
l9_entry.grid(row=12, column=2)
l10_entry.grid(row=13, column=2)
l11_entry.grid(row=14, column=2)
l12_entry.grid(row=15, column=2)
l13_entry.grid(row=16, column=2)
l14_entry.grid(row=17, column=2)
l15_entry.grid(row=18, column=2)
l16_entry.grid(row=19, column=2)

# Entry for WGR
l17_entry.grid(row=12, column=3)
l18_entry.grid(row=13, column=3)
l19_entry.grid(row=14, column=3)
l20_entry.grid(row=15, column=3)
l21_entry.grid(row=16, column=3)
l22_entry.grid(row=17, column=3)
l23_entry.grid(row=18, column=3)
l24_entry.grid(row=19, column=3)

# Entry for Pres
l25_entry.grid(row=12, column=4)
l26_entry.grid(row=13, column=4)
l27_entry.grid(row=14, column=4)
l28_entry.grid(row=15, column=4)
l29_entry.grid(row=16, column=4)
l30_entry.grid(row=17, column=4)
l31_entry.grid(row=18, column=4)
l32_entry.grid(row=19, column=4)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 5th Attempt

# %%
root = Tk()
root.geometry("1000x3000")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato24, bg='gold')
# Equrve_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo/equrve.png"))
# Equrve_imagelabel = Label(image=Equrve_image)
# Eqaims_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo//eqaims.png"))
# Eqaims_imagelabel = Label(image=Eqaims_image)

# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=40, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)
TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)
TC_EUR_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=40, bg='#000000', fg='#ffffff')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)



### LAYOUT ###

# Header
app_head.grid(row=3, column=0, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
# Equrve_imagelabel.grid(row=0, column=0, columnspan=7, pady=(10,2))
# Eqaims_imagelabel.grid(row=0, column=6, columnspan=2, pady=(10,2))

# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
TC_EUR_label.grid(row=8, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))
TC_EUR_entry.grid(row=8, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))




### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=40, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR        Gas Rate        Qg(MMSCF/D)        Cum GP(BSCF)        No.of Day        Cum Days        Cum Mo        Cum Yr', font=roboto8)
table1 = scrolledtext.ScrolledText(root, height=40, width=100) 


table_label.grid(row=21, column=0, pady=(0,10), padx=(10,0))
tb1.grid(row=22, column=0, columnspan=5)
table1.grid(row=23, column=0, columnspan=5)


# Entry for Gas Rate
# l1_entry.grid(row=12, column=1, pady=0, padx=(8, 0))
# l2_entry.grid(row=13, column=1, pady=0, padx=(8, 0))
# l3_entry.grid(row=14, column=1, pady=0, padx=(8, 0))
# l4_entry.grid(row=15, column=1, pady=0, padx=(8, 0))
# l5_entry.grid(row=16, column=1, pady=0, padx=(8, 0))
# l6_entry.grid(row=17, column=1, pady=0, padx=(8, 0))
# l7_entry.grid(row=18, column=1, pady=0, padx=(8, 0))
# l8_entry.grid(row=19, column=1, pady=0, padx=(8, 0))

# Entry for Gas Rate
l1_entry.grid(row=12, column=1)
l2_entry.grid(row=13, column=1)
l3_entry.grid(row=14, column=1)
l4_entry.grid(row=15, column=1)
l5_entry.grid(row=16, column=1)
l6_entry.grid(row=17, column=1)
l7_entry.grid(row=18, column=1)
l8_entry.grid(row=19, column=1)

# Entry for CGR
l9_entry.grid(row=12, column=2)
l10_entry.grid(row=13, column=2)
l11_entry.grid(row=14, column=2)
l12_entry.grid(row=15, column=2)
l13_entry.grid(row=16, column=2)
l14_entry.grid(row=17, column=2)
l15_entry.grid(row=18, column=2)
l16_entry.grid(row=19, column=2)

# Entry for WGR
l17_entry.grid(row=12, column=3)
l18_entry.grid(row=13, column=3)
l19_entry.grid(row=14, column=3)
l20_entry.grid(row=15, column=3)
l21_entry.grid(row=16, column=3)
l22_entry.grid(row=17, column=3)
l23_entry.grid(row=18, column=3)
l24_entry.grid(row=19, column=3)

# Entry for Pres
l25_entry.grid(row=12, column=4)
l26_entry.grid(row=13, column=4)
l27_entry.grid(row=14, column=4)
l28_entry.grid(row=15, column=4)
l29_entry.grid(row=16, column=4)
l30_entry.grid(row=17, column=4)
l31_entry.grid(row=18, column=4)
l32_entry.grid(row=19, column=4)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 6th Attempt

# %%
root = Tk()
root.geometry("1300x700")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato24, bg='gold')
# Equrve_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo/equrve.png"))
# Equrve_imagelabel = Label(image=Equrve_image)
# Eqaims_image = ImageTk.PhotoImage(Image.open("F:/Python O&G Notebooks/EQ/Logo//eqaims.png"))
# Eqaims_imagelabel = Label(image=Eqaims_image)

# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)
TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)
TC_EUR_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)



### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
# Equrve_imagelabel.grid(row=0, column=0, columnspan=7, pady=(10,2))
# Eqaims_imagelabel.grid(row=0, column=6, columnspan=2, pady=(10,2))

# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
TC_EUR_label.grid(row=8, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))
TC_EUR_entry.grid(row=8, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=80, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR          Gas Rate          Qg(MMSCF/D)          Cum GP(BSCF)          No.of Day          Cum Days          Cum Mo         Cum Yr', bg='light grey')
table1 = scrolledtext.ScrolledText(root, height=23, width=80) 


table_label.grid(row=5, column=9, columnspan=2,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='Execute', font=lato10, width=10, bg='#000000', fg='#ffffff')
run_b = Button(root, text='Run', width=10)
clear_b = Button(root, text='Clear', width=10)
exit_b = Button(root, text='Exit', width=10)

execute_label.grid(row=5, column=3, pady=(0,10), padx=(10,0))
run_b.grid(row=6, column=3, pady=5, padx=(5, 0))
clear_b.grid(row=7, column=3, pady=5, padx=(5, 0))
exit_b.grid(row=8, column=3, pady=5, padx=(5, 0))

# run_b.grid(row=22, column=1, pady=5, padx=(5, 0))
# clear_b.grid(row=22, column=2, pady=5, padx=(5, 0))
# exit_b.grid(row=22, column=3, pady=5, padx=(5, 0))

### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 7th Attempt

# %%
root = Tk()
root.geometry("1300x700")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='gold')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)
# TC_EUR_label = Label(root, text='Type Curves vs. %EUR', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)
# TC_EUR_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)



### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))

# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
# TC_EUR_label.grid(row=8, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))
# TC_EUR_entry.grid(row=8, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=80, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR          Gas Rate          Qg(MMSCF/D)          Cum GP(BSCF)          No.of Day          Cum Days          Cum Mo         Cum Yr', bg='light grey')
table1 = scrolledtext.ScrolledText(root, height=23, width=80) 


table_label.grid(row=5, column=9, columnspan=2,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='Run Button', font=lato10, width=10, bg='#000000', fg='#ffffff')
run_b = Button(root, text='AIMS', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10)

execute_label.grid(row=5, column=3, pady=(0,10), padx=(10,0))
run_b.grid(row=6, column=3, pady=5, padx=(5, 0))
clear_b.grid(row=7, column=3, pady=5, padx=(5, 0))
exit_b.grid(row=8, column=3, pady=5, padx=(5, 0))

# run_b.grid(row=22, column=1, pady=5, padx=(5, 0))
# clear_b.grid(row=22, column=2, pady=5, padx=(5, 0))
# exit_b.grid(row=22, column=3, pady=5, padx=(5, 0))

### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 8th Attempt

# %%
root = Tk()
root.geometry("1300x700")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='light grey')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)


### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))

# app_head.grid(row=3, column=0, pady=(0, 20))
# # app_head.grid(row=3, column=0, columnspan=7)
# Equrve_imagelabel.grid(row=0, column=0, columnspan=2, pady=(10,2))
# Eqaims_imagelabel.grid(row=0, column=3, columnspan=5, pady=(10,2))


# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=80, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR          Gas Rate          Qg(MMSCF/D)          Cum GP(BSCF)          No.of Day          Cum Days          Cum Mo         Cum Yr', bg='light grey')
table1 = scrolledtext.ScrolledText(root, height=23, width=80) 


table_label.grid(row=5, column=9, columnspan=2,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='AIMS EQURVE', font=lato10, width=20, bg='#000000', fg='#ffffff')
run_b = Button(root, text='RUN', width=10, font=lato10)
plot_b = Button(root, text='Plot', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10)

execute_label.grid(row=5, column=2, pady=(0,10), padx=(10,0), columnspan=3)
run_b.grid(row=6, column=2, pady=5, padx=(5, 0), columnspan=2)
plot_b.grid(row=6, column=3, pady=5, padx=(5, 0), columnspan=2)
clear_b.grid(row=7, column=2, pady=5, padx=(5, 0), columnspan=2)
exit_b.grid(row=7, column=3, pady=5, padx=(5, 0), columnspan=2)

# run_b.grid(row=22, column=1, pady=5, padx=(5, 0))
# clear_b.grid(row=22, column=2, pady=5, padx=(5, 0))
# exit_b.grid(row=22, column=3, pady=5, padx=(5, 0))

### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 9th Attempt

# %%
root = Tk()
root.geometry("1550x700")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='light grey')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)


### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))


# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=117, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR         Gas Rate         CGR_CGRi         WGR         Pr_Pi         Qg         CGR         PRES         Cum_Gp         No_of_Day         Cum_Days         Cum_Mo         Cum_Yr       Qc       Qw', bg='light grey')
table1 = scrolledtext.ScrolledText(root, height=20, width=115) 


table_label.grid(row=5, column=9, columnspan=2,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='AIMS EQURVE', font=lato10, width=20, bg='#000000', fg='#ffffff')
run_b = Button(root, text='RUN', width=10, font=lato10)
plot_b = Button(root, text='Plot', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10)

execute_label.grid(row=5, column=2, pady=(0,10), padx=(10,0), columnspan=3)
run_b.grid(row=6, column=2, pady=5, padx=(5, 0), columnspan=2)
plot_b.grid(row=6, column=3, pady=5, padx=(5, 0), columnspan=2)
clear_b.grid(row=7, column=2, pady=5, padx=(5, 0), columnspan=2)
exit_b.grid(row=7, column=3, pady=5, padx=(5, 0), columnspan=2)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 10th Attempt

# %%
root = Tk()
root.geometry("1800x880")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='light grey')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)


# Reservoir Input
# Label
res_input_label = Label(root, text='Reservoir Input', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_param_label = Label(root, text='Reservoir Parameter', font=lato10, bg='light grey')
e1_label = Label(root, text='EUR (BSCF)', font=roboto8, bg='light grey', justify=LEFT)
e2_label = Label(root, text='Pi (psia)', font=roboto8, bg='light grey', justify=LEFT)
e3_label = Label(root, text='CGRi (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e4_label = Label(root, text='Qg_abd (MMSCF/D)', font=roboto8, bg='light grey', justify=LEFT)
e5_label = Label(root, text='Pabd (psia)', font=roboto8, bg='light grey', justify=LEFT)
e6_label = Label(root, text='CGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e7_label = Label(root, text='WGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e8_label = Label(root, text='Downtime (%)', font=roboto8, bg='light grey', justify=LEFT)

# Label grid
res_input_label.grid(row=21, column=0, pady=(0,10), padx=(10,0))
res_param_label.grid(row=22, column=0)
e1_label.grid(row=23, column=0, pady=5, padx=(5, 0))
e2_label.grid(row=24, column=0, pady=5, padx=(5, 0))
e3_label.grid(row=25, column=0, pady=5, padx=(5, 0))
e4_label.grid(row=26, column=0, pady=5, padx=(5, 0))
e5_label.grid(row=27, column=0, pady=5, padx=(5, 0))
e6_label.grid(row=28, column=0, pady=5, padx=(5, 0))
e7_label.grid(row=29, column=0, pady=5, padx=(5, 0))
e8_label.grid(row=30, column=0, pady=5, padx=(5, 0))

# Entry
e1_entry = Entry(root, font=roboto8, width=15)
e2_entry = Entry(root, font=roboto8, width=15)
e3_entry = Entry(root, font=roboto8, width=15)
e4_entry = Entry(root, font=roboto8, width=15)
e5_entry = Entry(root, font=roboto8, width=15)
e6_entry = Entry(root, font=roboto8, width=15)
e7_entry = Entry(root, font=roboto8, width=15)
e8_entry = Entry(root, font=roboto8, width=15)

# Entry grid

e1_entry.grid(row=23, column=1, pady=5, padx=(5, 0))
e2_entry.grid(row=24, column=1, pady=5, padx=(5, 0))
e3_entry.grid(row=25, column=1, pady=5, padx=(5, 0))
e4_entry.grid(row=26, column=1, pady=5, padx=(5, 0))
e5_entry.grid(row=27, column=1, pady=5, padx=(5, 0))
e6_entry.grid(row=28, column=1, pady=5, padx=(5, 0))
e7_entry.grid(row=29, column=1, pady=5, padx=(5, 0))
e8_entry.grid(row=30, column=1, pady=5, padx=(5, 0))





### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))


# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=144, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR         Gas Rate         CGR_CGRi         WGR         Pr_Pi         Qg         CGR         PRES         Cum_Gp         No_of_Day         Cum_Days         Cum_Mo         Cum_Yr       Qc       Qw', bg='light grey', font=lato10)
table1 = scrolledtext.ScrolledText(root, height=30, width=142) 


table_label.grid(row=5, column=9, columnspan=3,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='AIMS EQURVE', font=lato10, width=20, bg='#000000', fg='#ffffff')
run_b = Button(root, text='RUN', width=10, font=lato10)
plot_b = Button(root, text='Plot', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10)

execute_label.grid(row=5, column=2, pady=(0,10), padx=(10,0), columnspan=3)
run_b.grid(row=6, column=2, pady=5, padx=(5, 0), columnspan=2)
plot_b.grid(row=6, column=3, pady=5, padx=(5, 0), columnspan=2)
clear_b.grid(row=7, column=2, pady=5, padx=(5, 0), columnspan=2)
exit_b.grid(row=7, column=3, pady=5, padx=(5, 0), columnspan=2)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 11th Attempt

# %%
root = Tk()
root.geometry("1800x800")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")


### WIDGET CREATION ###

# Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='light grey')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)


# FIELD INFO

Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)

res_entry = Entry(root, font=roboto8, width=15)
inc_entry = Entry(root, font=roboto8, width=15)


# TYPE CURVE EDITOR

TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')


l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Gas Rate
l1_entry = Entry(root, font=roboto8, width=15)
l2_entry = Entry(root, font=roboto8, width=15)
l3_entry = Entry(root, font=roboto8, width=15)
l4_entry = Entry(root, font=roboto8, width=15)
l5_entry = Entry(root, font=roboto8, width=15)
l6_entry = Entry(root, font=roboto8, width=15)
l7_entry = Entry(root, font=roboto8, width=15)
l8_entry = Entry(root, font=roboto8, width=15)

# CGR
l9_entry = Entry(root, font=roboto8, width=15)
l10_entry = Entry(root, font=roboto8, width=15)
l11_entry = Entry(root, font=roboto8, width=15)
l12_entry = Entry(root, font=roboto8, width=15)
l13_entry = Entry(root, font=roboto8, width=15)
l14_entry = Entry(root, font=roboto8, width=15)
l15_entry = Entry(root, font=roboto8, width=15)
l16_entry = Entry(root, font=roboto8, width=15)

# WGR
l17_entry = Entry(root, font=roboto8, width=15)
l18_entry = Entry(root, font=roboto8, width=15)
l19_entry = Entry(root, font=roboto8, width=15)
l20_entry = Entry(root, font=roboto8, width=15)
l21_entry = Entry(root, font=roboto8, width=15)
l22_entry = Entry(root, font=roboto8, width=15)
l23_entry = Entry(root, font=roboto8, width=15)
l24_entry = Entry(root, font=roboto8, width=15)

# Pres 
l25_entry = Entry(root, font=roboto8, width=15)
l26_entry = Entry(root, font=roboto8, width=15)
l27_entry = Entry(root, font=roboto8, width=15)
l28_entry = Entry(root, font=roboto8, width=15)
l29_entry = Entry(root, font=roboto8, width=15)
l30_entry = Entry(root, font=roboto8, width=15)
l31_entry = Entry(root, font=roboto8, width=15)
l32_entry = Entry(root, font=roboto8, width=15)


# Reservoir Input
# Label
res_input_label = Label(root, text='Reservoir Input', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_param_label = Label(root, text='Reservoir Parameter', font=lato10, bg='light grey')
e1_label = Label(root, text='Qg_abd (MMSCF/D)', font=roboto8, bg='light grey', justify=LEFT)
e2_label = Label(root, text='CGRi (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e3_label = Label(root, text='CGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e4_label = Label(root, text='WGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e5_label = Label(root, text='EUR (BSCF)', font=roboto8, bg='light grey', justify=LEFT)
e6_label = Label(root, text='Pi (psia)', font=roboto8, bg='light grey', justify=LEFT)
e7_label = Label(root, text='Pabd (psia)', font=roboto8, bg='light grey', justify=LEFT)
e8_label = Label(root, text='Downtime (%)', font=roboto8, bg='light grey', justify=LEFT)

# Label grid
res_input_label.grid(row=21, column=0, pady=(0,10), padx=(10,0))
res_param_label.grid(row=22, column=0)
e1_label.grid(row=23, column=0, pady=5, padx=(5, 0))
e2_label.grid(row=24, column=0, pady=5, padx=(5, 0))
e3_label.grid(row=25, column=0, pady=5, padx=(5, 0))
e4_label.grid(row=26, column=0, pady=5, padx=(5, 0))
e5_label.grid(row=23, column=2, pady=5, padx=(5, 0))
e6_label.grid(row=24, column=2, pady=5, padx=(5, 0))
e7_label.grid(row=25, column=2, pady=5, padx=(5, 0))
e8_label.grid(row=26, column=2, pady=5, padx=(5, 0))

# Entry
e1_entry = Entry(root, font=roboto8, width=15)
e2_entry = Entry(root, font=roboto8, width=15)
e3_entry = Entry(root, font=roboto8, width=15)
e4_entry = Entry(root, font=roboto8, width=15)
e5_entry = Entry(root, font=roboto8, width=15)
e6_entry = Entry(root, font=roboto8, width=15)
e7_entry = Entry(root, font=roboto8, width=15)
e8_entry = Entry(root, font=roboto8, width=15)

# Entry grid

e1_entry.grid(row=23, column=1, pady=5, padx=(5, 0))
e2_entry.grid(row=24, column=1, pady=5, padx=(5, 0))
e3_entry.grid(row=25, column=1, pady=5, padx=(5, 0))
e4_entry.grid(row=26, column=1, pady=5, padx=(5, 0))
e5_entry.grid(row=23, column=3, pady=5, padx=(5, 0))
e6_entry.grid(row=24, column=3, pady=5, padx=(5, 0))
e7_entry.grid(row=25, column=3, pady=5, padx=(5, 0))
e8_entry.grid(row=26, column=3, pady=5, padx=(5, 0))


### LAYOUT ###

# Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
# app_head.grid(row=3, column=0, columnspan=7)
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))


# FIELD INFO
# Label
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))

# Entry
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))

# TYPE CURVE EDITOR
# Label
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))


# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### Table Output ###
table_label = Label(root, text='Table Dataframe', font=lato10, width=144, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR         Gas Rate         CGR_CGRi         WGR         Pr_Pi         Qg         CGR         PRES         Cum_Gp         No_of_Day         Cum_Days         Cum_Mo         Cum_Yr       Qc       Qw', bg='light grey', font=lato10)
table1 = scrolledtext.ScrolledText(root, height=30, width=142) 


table_label.grid(row=5, column=9, columnspan=3,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))
# table1.insert('Hello')


### Button ###

execute_label = Label(root, text='AIMS EQURVE', font=lato10, width=20, bg='#000000', fg='#ffffff')
run_b = Button(root, text='RUN', width=10, font=lato10)
plot_b = Button(root, text='Plot', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10)

execute_label.grid(row=5, column=2, pady=(0,10), padx=(10,0), columnspan=3)
run_b.grid(row=6, column=2, pady=5, padx=(5, 0), columnspan=2)
plot_b.grid(row=6, column=3, pady=5, padx=(5, 0), columnspan=2)
clear_b.grid(row=7, column=2, pady=5, padx=(5, 0), columnspan=2)
exit_b.grid(row=7, column=3, pady=5, padx=(5, 0), columnspan=2)


### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# ## 12th Attempt

# %%
root = Tk()
root.geometry("1800x800")
root.title('EQ-AIMS - EQURVE GAS')
root.config(background='light grey')
root.iconbitmap('F:\Python O&G Notebooks\EQ\Logo\eqaimsicon.ico')

lato24 = tkFont.Font(family="Lato",size=24,weight="bold")
lato18 = tkFont.Font(family="Lato",size=16,weight="normal")
roboto8 = tkFont.Font(family="Roboto",size=8)
lato10 = tkFont.Font(family="Lato", size=10, weight="bold")
lato12 = tkFont.Font(family="Lato", size=12, weight="bold")

### WIDGET CREATION ###
# Label Header
app_head = Label(root, text="EQURVE - GAS", font=lato18, bg='light grey')
Equrve_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\equrve.png"))
Equrve_imagelabel = Label(image=Equrve_image)
Eqaims_image = ImageTk.PhotoImage(Image.open("F:\Python O&G Notebooks\EQ\Logo\eqaims.png"))
Eqaims_imagelabel = Label(image=Eqaims_image)

### LAYOUT ###
# Grid Header
app_head.grid(row=3, column=2, columnspan=7, pady=(0, 20))
Equrve_imagelabel.grid(row=0, column=2, columnspan=7, pady=(10,2))
Eqaims_imagelabel.grid(row=0, column=7, columnspan=10, pady=(10,2))


### WIDGET CREATION ###
### FIELD INFO ##
# Label
Field_label = Label(root, text='FIELD INFO', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_label = Label(root, text='Field/Reservoir', font=roboto8, bg='light grey', justify=LEFT)
inc_label = Label(root, text='Increment', font=roboto8, bg='light grey', justify=LEFT)

res_entry_text = StringVar()
inc_entry_text = StringVar()

res_entry = Entry(root, font=roboto8, width=15, textvariable=res_entry_text)
inc_entry = Entry(root, font=roboto8, width=15, textvariable=inc_entry_text)


### LAYOUT ###
# Grid 
Field_label.grid(row=5, column=0, pady=(0,10), padx=(10,0))
res_label.grid(row=6, column=0, pady=5, padx=(10, 0))
inc_label.grid(row=7, column=0, pady=5, padx=(10,0))
res_entry.grid(row=6, column=1, pady=0, padx=(8, 0))
inc_entry.grid(row=7, column=1, pady=0, padx=(8,0))


### WIDGET CREATION ###
### TYPE CURVE EDITOR ###
# Label
TC_label = Label(root, text='TYPE CURVE EDITOR', font=lato10, width=20, bg='#000000', fg='#ffffff')
TC_EUR_label = Label(root, text='Type Curves vs %EUR', font=lato10, bg='light grey')
gasrate_label = Label(root, text='GAS RATE', font=lato10, bg='light grey')
CGR_label = Label(root, text='CGR', font=lato10, bg='light grey')
WGR_label = Label(root, text='WGR', font=lato10, bg='light grey')
Pres_label = Label(root, text='Pres', font=lato10, bg='light grey')

l1_label = Label(root, text='End of Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l2_label = Label(root, text='Initial Incline Period', font=roboto8, bg='light grey', justify=LEFT)
l3_label = Label(root, text='Incline Factor', font=roboto8, bg='light grey', justify=LEFT)
l4_label = Label(root, text='End of Plateau Period', font=roboto8, bg='light grey', justify=LEFT)
l5_label = Label(root, text='Plateau Rate', font=roboto8, bg='light grey', justify=LEFT)
l6_label = Label(root, text='Start of Decline Period', font=roboto8, bg='light grey', justify=LEFT)
l7_label = Label(root, text='Initial Decline Rate', font=roboto8, bg='light grey', justify=LEFT)
l8_label = Label(root, text='Decline Factor', font=roboto8, bg='light grey', justify=LEFT)

# Entry
# Gas Rate
end_incl_per_GR = StringVar()
ini_incl_rate_GR = StringVar()
incl_fact_GR = StringVar()
end_plat_per_GR = StringVar()
plat_rate_GR = StringVar()
str_dec_per_GR = StringVar()
ini_dec_rate_GR = StringVar()
dec_fact_GR = StringVar()

l1_entry = Entry(root, font=roboto8, width=15, textvariable=end_incl_per_GR)
l2_entry = Entry(root, font=roboto8, width=15, textvariable=ini_incl_rate_GR)
l3_entry = Entry(root, font=roboto8, width=15, textvariable=incl_fact_GR)
l4_entry = Entry(root, font=roboto8, width=15, textvariable=end_plat_per_GR)
l5_entry = Entry(root, font=roboto8, width=15, textvariable=plat_rate_GR)
l6_entry = Entry(root, font=roboto8, width=15, textvariable=str_dec_per_GR)
l7_entry = Entry(root, font=roboto8, width=15, textvariable=ini_dec_rate_GR)
l8_entry = Entry(root, font=roboto8, width=15, textvariable=dec_fact_GR)

# CGR
end_incl_per_CGR = StringVar()
ini_incl_rate_CGR = StringVar()
incl_fact_CGR = StringVar()
end_plat_per_CGR = StringVar()
plat_rate_CGR = StringVar()
str_dec_per_CGR = StringVar()
ini_dec_rate_CGR = StringVar()
dec_fact_CGR = StringVar()

l9_entry = Entry(root, font=roboto8, width=15, textvariable=end_incl_per_CGR)
l10_entry = Entry(root, font=roboto8, width=15, textvariable=ini_incl_rate_CGR)
l11_entry = Entry(root, font=roboto8, width=15, textvariable=incl_fact_CGR)
l12_entry = Entry(root, font=roboto8, width=15, textvariable=end_plat_per_CGR)
l13_entry = Entry(root, font=roboto8, width=15, textvariable=plat_rate_CGR)
l14_entry = Entry(root, font=roboto8, width=15, textvariable=str_dec_per_CGR)
l15_entry = Entry(root, font=roboto8, width=15, textvariable=ini_dec_rate_CGR)
l16_entry = Entry(root, font=roboto8, width=15, textvariable=dec_fact_CGR)

# WGR
end_incl_per_WGR = StringVar()
ini_incl_rate_WGR = StringVar()
incl_fact_WGR = StringVar()
end_plat_per_WGR = StringVar()
plat_rate_WGR = StringVar()
str_dec_per_WGR = StringVar()
ini_dec_rate_WGR = StringVar()
dec_fact_WGR = StringVar()

l17_entry = Entry(root, font=roboto8, width=15, textvariable=end_incl_per_WGR)
l18_entry = Entry(root, font=roboto8, width=15, textvariable=ini_incl_rate_WGR)
l19_entry = Entry(root, font=roboto8, width=15, textvariable=incl_fact_WGR)
l20_entry = Entry(root, font=roboto8, width=15, textvariable=end_plat_per_WGR)
l21_entry = Entry(root, font=roboto8, width=15, textvariable=plat_rate_WGR)
l22_entry = Entry(root, font=roboto8, width=15, textvariable=str_dec_per_WGR)
l23_entry = Entry(root, font=roboto8, width=15, textvariable=ini_dec_rate_WGR)
l24_entry = Entry(root, font=roboto8, width=15, textvariable=dec_fact_WGR)

# Pres 
end_incl_per_PRES = StringVar()
ini_incl_rate_PRES = StringVar()
incl_fact_PRES = StringVar()
end_plat_per_PRES = StringVar()
plat_rate_PRES = StringVar()
str_dec_per_PRES = StringVar()
ini_dec_rate_PRES = StringVar()
dec_fact_PRES = StringVar()

l25_entry = Entry(root, font=roboto8, width=15, textvariable=end_incl_per_PRES)
l26_entry = Entry(root, font=roboto8, width=15, textvariable=ini_incl_rate_PRES)
l27_entry = Entry(root, font=roboto8, width=15, textvariable=incl_fact_PRES)
l28_entry = Entry(root, font=roboto8, width=15, textvariable=end_plat_per_PRES)
l29_entry = Entry(root, font=roboto8, width=15, textvariable=plat_rate_PRES)
l30_entry = Entry(root, font=roboto8, width=15, textvariable=str_dec_per_PRES)
l31_entry = Entry(root, font=roboto8, width=15, textvariable=ini_dec_rate_PRES)
l32_entry = Entry(root, font=roboto8, width=15, textvariable=dec_fact_PRES)


### LAYOUT ###
# Grid
TC_label.grid(row=10, column=0, pady=(0,10), padx=(10,0))
TC_EUR_label.grid(row=11, column=0)
gasrate_label.grid(row=11, column=1)
CGR_label.grid(row=11, column=2)
WGR_label.grid(row=11, column=3)
Pres_label.grid(row=11, column=4)

l1_label.grid(row=12, column=0, pady=5, padx=(5, 0))
l2_label.grid(row=13, column=0, pady=5, padx=(5, 0))
l3_label.grid(row=14, column=0, pady=5, padx=(5, 0))
l4_label.grid(row=15, column=0, pady=5, padx=(5, 0))
l5_label.grid(row=16, column=0, pady=5, padx=(5, 0))
l6_label.grid(row=17, column=0, pady=5, padx=(5, 0))
l7_label.grid(row=18, column=0, pady=5, padx=(5, 0))
l8_label.grid(row=19, column=0, pady=5, padx=(5, 0))

# Entry for Gas Rate
l1_entry.grid(row=12, column=1, pady=5, padx=(5, 0))
l2_entry.grid(row=13, column=1, pady=5, padx=(5, 0))
l3_entry.grid(row=14, column=1, pady=5, padx=(5, 0))
l4_entry.grid(row=15, column=1, pady=5, padx=(5, 0))
l5_entry.grid(row=16, column=1, pady=5, padx=(5, 0))
l6_entry.grid(row=17, column=1, pady=5, padx=(5, 0))
l7_entry.grid(row=18, column=1, pady=5, padx=(5, 0))
l8_entry.grid(row=19, column=1, pady=5, padx=(5, 0))

# Entry for CGR
l9_entry.grid(row=12, column=2, pady=5, padx=(5, 0))
l10_entry.grid(row=13, column=2, pady=5, padx=(5, 0))
l11_entry.grid(row=14, column=2, pady=5, padx=(5, 0))
l12_entry.grid(row=15, column=2, pady=5, padx=(5, 0))
l13_entry.grid(row=16, column=2, pady=5, padx=(5, 0))
l14_entry.grid(row=17, column=2, pady=5, padx=(5, 0))
l15_entry.grid(row=18, column=2, pady=5, padx=(5, 0))
l16_entry.grid(row=19, column=2, pady=5, padx=(5, 0))

# Entry for WGR
l17_entry.grid(row=12, column=3, pady=5, padx=(5, 0))
l18_entry.grid(row=13, column=3, pady=5, padx=(5, 0))
l19_entry.grid(row=14, column=3, pady=5, padx=(5, 0))
l20_entry.grid(row=15, column=3, pady=5, padx=(5, 0))
l21_entry.grid(row=16, column=3, pady=5, padx=(5, 0))
l22_entry.grid(row=17, column=3, pady=5, padx=(5, 0))
l23_entry.grid(row=18, column=3, pady=5, padx=(5, 0))
l24_entry.grid(row=19, column=3, pady=5, padx=(5, 0))

# Entry for Pres
l25_entry.grid(row=12, column=4, pady=5, padx=(5, 0))
l26_entry.grid(row=13, column=4, pady=5, padx=(5, 0))
l27_entry.grid(row=14, column=4, pady=5, padx=(5, 0))
l28_entry.grid(row=15, column=4, pady=5, padx=(5, 0))
l29_entry.grid(row=16, column=4, pady=5, padx=(5, 0))
l30_entry.grid(row=17, column=4, pady=5, padx=(5, 0))
l31_entry.grid(row=18, column=4, pady=5, padx=(5, 0))
l32_entry.grid(row=19, column=4, pady=5, padx=(5, 0))


### WIDGET CREATION ###
### Reservoir Input ###
# Label
res_input_label = Label(root, text='Reservoir Input', font=lato10, width=20, bg='#000000', fg='#ffffff')
res_param_label = Label(root, text='Reservoir Parameter', font=lato10, bg='light grey')
e1_label = Label(root, text='Qg_abd (MMSCF/D)', font=roboto8, bg='light grey', justify=LEFT)
e2_label = Label(root, text='CGRi (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e3_label = Label(root, text='CGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e4_label = Label(root, text='WGR_limit (STB/MMSCF)', font=roboto8, bg='light grey', justify=LEFT)
e5_label = Label(root, text='EUR (BSCF)', font=roboto8, bg='light grey', justify=LEFT)
e6_label = Label(root, text='Pi (psia)', font=roboto8, bg='light grey', justify=LEFT)
e7_label = Label(root, text='Pabd (psia)', font=roboto8, bg='light grey', justify=LEFT)
e8_label = Label(root, text='Downtime (%)', font=roboto8, bg='light grey', justify=LEFT)

# Entry
Qg_abd_text = StringVar()
CGRi_text = StringVar()
CGR_limit_text = StringVar()
WGR_limit_text = StringVar()
EUR_text = StringVar()
Pi_text = StringVar()
Pabd_text = StringVar()
Downtime_text = StringVar()

e1_entry = Entry(root, font=roboto8, width=15, textvariable=Qg_abd_text)
e2_entry = Entry(root, font=roboto8, width=15, textvariable=CGRi_text)
e3_entry = Entry(root, font=roboto8, width=15, textvariable=CGR_limit_text)
e4_entry = Entry(root, font=roboto8, width=15, textvariable=WGR_limit_text)
e5_entry = Entry(root, font=roboto8, width=15, textvariable=EUR_text)
e6_entry = Entry(root, font=roboto8, width=15, textvariable=Pi_text)
e7_entry = Entry(root, font=roboto8, width=15, textvariable=Pabd_text)
e8_entry = Entry(root, font=roboto8, width=15, textvariable=Downtime_text)

### LAYOUT ###
# Grid
res_input_label.grid(row=21, column=0, pady=(0,10), padx=(10,0))
res_param_label.grid(row=22, column=0)
e1_label.grid(row=23, column=0, pady=5, padx=(5, 0))
e2_label.grid(row=24, column=0, pady=5, padx=(5, 0))
e3_label.grid(row=25, column=0, pady=5, padx=(5, 0))
e4_label.grid(row=26, column=0, pady=5, padx=(5, 0))
e5_label.grid(row=23, column=2, pady=5, padx=(5, 0))
e6_label.grid(row=24, column=2, pady=5, padx=(5, 0))
e7_label.grid(row=25, column=2, pady=5, padx=(5, 0))
e8_label.grid(row=26, column=2, pady=5, padx=(5, 0))

e1_entry.grid(row=23, column=1, pady=5, padx=(5, 0))
e2_entry.grid(row=24, column=1, pady=5, padx=(5, 0))
e3_entry.grid(row=25, column=1, pady=5, padx=(5, 0))
e4_entry.grid(row=26, column=1, pady=5, padx=(5, 0))
e5_entry.grid(row=23, column=3, pady=5, padx=(5, 0))
e6_entry.grid(row=24, column=3, pady=5, padx=(5, 0))
e7_entry.grid(row=25, column=3, pady=5, padx=(5, 0))
e8_entry.grid(row=26, column=3, pady=5, padx=(5, 0))


### WIDGET CREATION ###  
### Table Output ###
# Label
table_label = Label(root, text='Table Dataframe', font=lato10, width=144, bg='#000000', fg='#ffffff')
tb1 = Label(root, text='%EUR         Gas Rate         CGR_CGRi         WGR         Pr_Pi         Qg         CGR         PRES         Cum_Gp         No_of_Day         Cum_Days         Cum_Mo         Cum_Yr       Qc       Qw', bg='light grey', font=lato10)
table1 = scrolledtext.ScrolledText(root, height=30, width=142) 

### LAYOUT ###
# Grid
table_label.grid(row=5, column=9, columnspan=3,pady=(0,10), padx=(10,0))
tb1.grid(row=6, column=9, columnspan=2, pady=(0,10), padx=(10,0))
table1.grid(row=7, column=9, rowspan=19, pady=(0,10), padx=(10,0))


### Button ###
### WIDGET CREATION ###
# Label
execute_label = Label(root, text='AIMS EQURVE', font=lato10, width=23, bg='#000000', fg='#ffffff')
run_b = Button(root, text='RUN', width=10, font=lato10)
plot_b = Button(root, text='Plot', width=10, font=lato10)
clear_b = Button(root, text='Clear', width=10, font=lato10)
exit_b = Button(root, text='Exit', width=10, font=lato10, command=root.destroy)
              
### LAYOUT ###              
# Grid
execute_label.grid(row=5, column=2, pady=(0,10), padx=(10,0), columnspan=3)
run_b.grid(row=6, column=2, pady=5, padx=(5, 0), columnspan=2)
plot_b.grid(row=6, column=3, pady=5, padx=(5, 0), columnspan=2)
clear_b.grid(row=7, column=2, pady=5, padx=(5, 0), columnspan=2)
exit_b.grid(row=7, column=3, pady=5, padx=(5, 0), columnspan=2)
    
       
### Creating Menubar ###
menubar = Menu(root)

# Adding File Menu and commands
file = Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=file)
file.add_command(label='New File', command=None)
file.add_command(label='Open...', command=None)
file.add_command(label='Save', command=None)
file.add_separator
file.add_command(label='Exit', command=root.destroy)

# Adding Edit Menu and commands
edit = Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=edit)
edit.add_command(label='Cut', command=None)
edit.add_command(label='Copy', command=None)
edit.add_command(label='Paste', command=None)
edit.add_command(label='Select All', command=None)
edit.add_separator
edit.add_command(label='Find...', command=None)
edit.add_command(label='Find Again', command=None)

# Adding Help Menu
help_=Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=help_)
help_.add_command(label='Demo', command=None)
help_.add_separator
help_.add_command(label='About', command=None)

# Display Menu
root.config(menu=menubar)
root.mainloop()
